# %% [markdown]
# # 宛名書き検証

# %%
# !ls
# Out:
# Dockerfile   codecov.yml	  samples    tests.py
# LICENSE      custom		  setup.cfg  trdg
# MANIFEST.in  requirements-hw.txt  setup.py   宛名書き作成検証.ipynb
# README.md    requirements.txt	  tests

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - 縦書きの画像生成にて、日本語の伸ばし棒の向きをいい感じにできるのか検証

# %%
from trdg.generators import (
    # GeneratorFromDict,
    # GeneratorFromRandom,
    GeneratorFromStrings,
    # GeneratorFromWikipedia,
)
# Out:
# Missing modules for handwritten text generation.

# %%
INPUT_TEXT_LIST = ['東京都 千代田区 霞が関一丁目二ー二', 'アドバイザー', 'リーダー', 'コミックマーケット', '大阪府大阪市北区中之島１ー３ー２０', 'ーーーーーーーーーーーーーーーーーーーーーーーー']
INPUT_ALPHABET_LIST = ['Test1', 'Test2', 'Test3']

# %%
INPUT_ALPHABET_LIST
# Out:
# ['Test1', 'Test2', 'Test3']

# %%
generator = GeneratorFromStrings(
    strings=INPUT_TEXT_LIST,
    count=len(INPUT_TEXT_LIST),
    blur=0.12,
    random_blur=True,
    text_color='#000000',
    language='ja',
    size=100,
    word_split=True,
    orientation = 1,
)
for img, lbl in generator:
    print(lbl)
    plt.imshow(np.array(img))
    plt.show()
    plt.close()
# Out:
# text_width: 100  text_height: 1655
# 東京都 千代田区 霞が関一丁目二ー二
# text_width: 100  text_height: 547
# アドバイザー
# text_width: 100  text_height: 359
# リーダー
# text_width: 100  text_height: 809
# コミックマーケット
# text_width: 100  text_height: 1567
# 大阪府大阪市北区中之島１ー３ー２０
# text_width: 100  text_height: 2728
# ーーーーーーーーーーーーーーーーーーーーーーーーーーーーーーー
